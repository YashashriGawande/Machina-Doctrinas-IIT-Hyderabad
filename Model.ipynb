# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Data Import

# %%
df=pd.read_csv('Public Data.csv')

# %% [markdown]
# Data Description

# %%
df.head(5)
# Out:
#    Unnamed: 0      Country  Year      Status  Power Level  Civilian Deaths  \
# 0           1  Afghanistan  2022  Developing        59.73            271.0
# 1           2  Afghanistan  2021  Developing        60.50            268.0
# 2           3  Afghanistan  2020  Developing        60.09            271.0
# 3           4  Afghanistan  2019  Developing        58.88            279.0
# 4           5  Afghanistan  2018  Developing        59.26            272.0
#
#    Military Accidents  Substance Abuse  Military Investment  Air Force  ...  \
# 0                  62            -0.25                73.83       59.0  ...
# 1                  66            -0.67                73.66       71.0  ...
# 2                  70            -0.17                77.76       65.0  ...
# 3                  70             0.69                 6.95       72.0  ...
# 4                  74             0.07                79.82       70.0  ...
#
#    Submarines  Educational Investment  Literacy  Revolts     GDP  Population  \
# 0        58.0                    8.06      62.0    -0.21  612.86    327582.0
# 1        60.0                    8.08      65.0    -0.04  631.58  31731688.0
# 2        65.0                    8.71      70.0    -0.21  669.50   3696953.0
# 3        65.0                    8.34      72.0    -0.60   63.67   2978596.0
# 4        67.0                    9.40      66.0    -0.12  553.89   2883166.0
#
#    Offense  Defense  Political Stability  International Reputation
# 0    17.16    17.68                 0.44                     10.57
# 1    18.28    17.85                 0.72                     10.40
# 2    16.85    18.46                 0.99                      9.52
# 3    17.72    18.11                 0.84                      9.82
# 4    18.91    18.76                 0.52                      9.14
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (2755, 23)

# %%
df.size
# Out:
# 63365

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755 entries, 0 to 2754
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2755 non-null   int64
#  1   Country                   2755 non-null   object
#  2   Year                      2755 non-null   int64
#  3   Status                    2755 non-null   object
#  4   Power Level               2745 non-null   float64
#  5   Civilian Deaths           2745 non-null   float64
#  6   Military Accidents        2755 non-null   int64
#  7   Substance Abuse           2738 non-null   float64
#  8   Military Investment       2755 non-null   float64
#  9   Air Force                 2211 non-null   float64
#  10  Army                      2755 non-null   int64
#  11  Intelligence              2723 non-null   float64
#  12  Navy                      2755 non-null   int64
#  13  Submarines                2736 non-null   float64
#  14  Educational Investment    2710 non-null   float64
#  15  Literacy                  2736 non-null   float64
#  16  Revolts                   2755 non-null   float64
#  17  GDP                       2336 non-null   float64
#  18  Population                2144 non-null   float64
#  19  Offense                   2723 non-null   float64
#  20  Defense                   2723 non-null   float64
#  21  Political Stability       2598 non-null   float64
#  22  International Reputation  2602 non-null   float64
# dtypes: float64(16), int64(5), object(2)
# memory usage: 495.2+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0         Year  Power Level  Civilian Deaths  \
# count  2755.000000  2755.000000  2745.000000      2745.000000
# mean   1469.062795  2015.021779    69.053974       165.606193
# std     848.242549     4.328500     9.610152       125.877696
# min       1.000000  2008.000000    36.090000        -2.000000
# 25%     734.500000  2011.000000    62.870000        74.000000
# 50%    1469.000000  2015.000000    72.010000       144.000000
# 75%    2203.500000  2019.000000    75.620000       228.000000
# max    2937.000000  2022.000000    90.160000       721.000000
#
#        Military Accidents  Substance Abuse  Military Investment    Air Force  \
# count         2755.000000      2738.000000          2755.000000  2211.000000
# mean            30.763339         4.612863           787.129020    80.872908
# std            119.776471         4.079841          2043.524973    25.316113
# min             -9.000000        -1.470000            -1.440000    -2.000000
# 25%              1.000000         0.942500            10.325000    77.000000
# 50%              4.000000         3.710000            79.820000    91.000000
# 75%             22.500000         7.747500           490.535000    96.000000
# max           1797.000000        18.580000         19479.680000   105.000000
#
#                 Army  Intelligence  ...   Submarines  Educational Investment  \
# count    2755.000000   2723.000000  ...  2736.000000             2710.000000
# mean     2480.524138     38.023030  ...    82.475512                5.940052
# std     11666.603222     19.973359  ...    23.521699                2.544054
# min        -9.000000      0.820000  ...     0.000000               -0.090000
# 25%         1.000000     19.075000  ...    78.000000                4.232500
# 50%        17.000000     43.190000  ...    92.000000                5.770000
# 75%       374.500000     55.895000  ...    97.000000                7.540000
# max    212179.000000     87.570000  ...   108.000000               17.460000
#
#           Literacy      Revolts            GDP    Population      Offense  \
# count  2736.000000  2755.000000    2336.000000  2.144000e+03  2723.000000
# mean     82.254386     1.808407    7502.798523  1.286305e+07     4.852435
# std      24.022498     5.238361   14425.541381  6.255998e+07     4.470310
# min      -1.000000    -1.580000       2.460000  3.100000e+01    -1.090000
# 25%      78.000000    -0.080000     453.740000  1.922085e+05     1.565000
# 50%      92.000000     0.360000    1720.520000  1.361184e+06     3.350000
# 75%      97.000000     1.135000    5845.192500  7.292424e+06     7.215000
# max     107.000000    50.310000  119173.150000  1.293859e+09    27.620000
#
#            Defense  Political Stability  International Reputation
# count  2723.000000          2598.000000               2602.000000
# mean      4.908480             0.638776                 11.925008
# std       4.567235             0.535577                  3.409595
# min      -1.380000            -1.300000                 -1.000000
# 25%       1.560000             0.290000                 10.042500
# 50%       3.350000             0.650000                 12.245000
# 75%       7.230000             1.010000                 14.260000
# max      29.130000             2.350000                 21.130000
#
# [8 rows x 21 columns]

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                    0
# Country                       0
# Year                          0
# Status                        0
# Power Level                  10
# Civilian Deaths              10
# Military Accidents            0
# Substance Abuse              17
# Military Investment           0
# Air Force                   544
# Army                          0
# Intelligence                 32
# Navy                          0
# Submarines                   19
# Educational Investment       45
# Literacy                     19
# Revolts                       0
# GDP                         419
# Population                  611
# Offense                      32
# Defense                      32
# Political Stability         157
# International Reputation    153
# dtype: int64

# %%
df.isnull()
# Out:
#       Unnamed: 0  Country   Year  Status  Power Level  Civilian Deaths  \
# 0          False    False  False   False        False            False
# 1          False    False  False   False        False            False
# 2          False    False  False   False        False            False
# 3          False    False  False   False        False            False
# 4          False    False  False   False        False            False
# ...          ...      ...    ...     ...          ...              ...
# 2750       False    False  False   False        False            False
# 2751       False    False  False   False        False            False
# 2752       False    False  False   False        False            False
# 2753       False    False  False   False        False            False
# 2754       False    False  False   False        False            False
#
#       Military Accidents  Substance Abuse  Military Investment  Air Force  \
# 0                  False            False                False      False
# 1                  False            False                False      False
# 2                  False            False                False      False
# 3                  False            False                False      False
# 4                  False            False                False      False
# ...                  ...              ...                  ...        ...
# 2750               False            False                False      False
# 2751               False            False                False      False
# 2752               False            False                False      False
# 2753               False            False                False      False
# 2754               False            False                False      False
#
#       ...  Submarines  Educational Investment  Literacy  Revolts    GDP  \
# 0     ...       False                   False     False    False  False
# 1     ...       False                   False     False    False  False
# 2     ...       False                   False     False    False  False
# 3     ...       False                   False     False    False  False
# 4     ...       False                   False     False    False  False
# ...   ...         ...                     ...       ...      ...    ...
# 2750  ...       False                   False     False    False  False
# 2751  ...       False                   False     False    False  False
# 2752  ...       False                   False     False    False  False
# 2753  ...       False                   False     False    False  False
# 2754  ...       False                   False     False    False  False
#
#       Population  Offense  Defense  Political Stability  \
# 0          False    False    False                False
# 1          False    False    False                False
# 2          False    False    False                False
# 3          False    False    False                False
# 4          False    False    False                False
# ...          ...      ...      ...                  ...
# 2750       False    False    False                False
# 2751       False    False    False                False
# 2752       False    False    False                False
# 2753       False    False    False                False
# 2754       False    False    False                False
#
#       International Reputation
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 2750                     False
# 2751                     False
# 2752                     False
# 2753                     False
# 2754                     False
#
# [2755 rows x 23 columns]

# %%
sns.heatmap(df.isnull()).set(title = 'Missing Data', xlabel = 'Columns', ylabel = 'Data Points')
# Out:
# [Text(33.0, 0.5, 'Data Points'),
#  Text(0.5, 15.0, 'Columns'),
#  Text(0.5, 1.0, 'Missing Data')]
